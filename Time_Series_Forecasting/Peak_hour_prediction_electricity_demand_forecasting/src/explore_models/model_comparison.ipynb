# %%
import pycaret 
import pandas as pd
import os

# %%
base_dir = os.path.dirname(os.getcwd())
train_data_df = pd.read_csv(os.path.join(base_dir,'../data/splits/train_data.csv'))
train_data_df.head(10)
# Out:
#          Date  Hour   Load  temp_station_1  temp_station_2  temp_station_3  \
# 0  2005-01-01     1  857.0              43              46              40
# 1  2005-01-01     2  825.0              41              46              38
# 2  2005-01-01     3  800.0              40              46              37
# 3  2005-01-01     4  794.0              39              46              37
# 4  2005-01-01     5  802.0              38              46              37
# 5  2005-01-01     6  828.0              37              45              36
# 6  2005-01-01     7  870.0              37              45              37
# 7  2005-01-01     8  916.0              36              43              37
# 8  2005-01-01     9  978.0              36              52              38
# 9  2005-01-01    10  988.0              44              55              43
#
#    temp_station_4  temp_station_5  temp_station_6  temp_station_7  ...  \
# ...

# %% [markdown]
# ### Regresssion model comparisons

# %%
from pycaret.regression import *

# %%
reg_exp = setup(data=train_data_df, target='Load', session_id=123, fold= 3,train_size=0.8)
# Out:
# <style type="text/css">
# #T_d5eaa_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d5eaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5eaa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d5eaa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5eaa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5eaa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d5eaa_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d5eaa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5eaa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d5eaa_row1_col1" class="data row1 col1" >Load</td>
#     </tr>
#     <tr>
#       <th id="T_d5eaa_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_reg_models = compare_models(sort='RMSE',exclude ='lightgbm',n_select=3)
# Out:
# <style type="text/css">
# #T_c86a0 th {
#   text-align: left;
# }
# ...

# %%
for model in best_reg_models:
    plot_model(model, plot='feature')
